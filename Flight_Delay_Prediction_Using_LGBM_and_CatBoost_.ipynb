# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('Flight_delay.csv')

# %%
df.head()
# Out:
#    DayOfWeek        Date  DepTime  ArrTime  CRSArrTime UniqueCarrier  \
# 0          4  03-01-2019     1829     1959        1925            WN
# 1          4  03-01-2019     1937     2037        1940            WN
# 2          4  03-01-2019     1644     1845        1725            WN
# 3          4  03-01-2019     1452     1640        1625            WN
# 4          4  03-01-2019     1323     1526        1510            WN
#
#                   Airline  FlightNum TailNum  ActualElapsedTime  ...  TaxiIn  \
# 0  Southwest Airlines Co.       3920  N464WN                 90  ...       3
# 1  Southwest Airlines Co.        509  N763SW                240  ...       3
# 2  Southwest Airlines Co.       1333  N334SW                121  ...       6
# 3  Southwest Airlines Co.        675  N286WN                228  ...       7
# 4  Southwest Airlines Co.          4  N674AA                123  ...       4
#
#    TaxiOut  Cancelled  CancellationCode Diverted CarrierDelay WeatherDelay  \
# 0       10          0                 N        0            2            0
# 1        7          0                 N        0           10            0
# 2        8          0                 N        0            8            0
# 3        8          0                 N        0            3            0
# 4        9          0                 N        0            0            0
#
#   NASDelay  SecurityDelay  LateAircraftDelay
# 0        0              0                 32
# 1        0              0                 47
# 2        0              0                 72
# 3        0              0                 12
# 4        0              0                 16
#
# [5 rows x 29 columns]

# %% [markdown]
# # Select Columns

# %%
df = df[['DayOfWeek','Date','DepTime','Airline','Origin','Dest','CarrierDelay']]
df
# Out:
#         DayOfWeek        Date  DepTime                 Airline Origin Dest  \
# 0               4  03-01-2019     1829  Southwest Airlines Co.    IND  BWI
# 1               4  03-01-2019     1937  Southwest Airlines Co.    IND  LAS
# 2               4  03-01-2019     1644  Southwest Airlines Co.    IND  MCO
# 3               4  03-01-2019     1452  Southwest Airlines Co.    IND  PHX
# 4               4  03-01-2019     1323  Southwest Airlines Co.    IND  TPA
# ...           ...         ...      ...                     ...    ...  ...
# 484546          5  13-06-2019     1609  American Airlines Inc.    DFW  MCO
# 484547          6  14-06-2019     1616  American Airlines Inc.    DFW  MCO
# 484548          2  17-06-2019     1617  American Airlines Inc.    DFW  MCO
# 484549          7  22-06-2019     1607  American Airlines Inc.    DFW  MCO
# 484550          1  23-06-2019     1608  American Airlines Inc.    DFW  MCO
#
#         CarrierDelay
# 0                  2
# 1                 10
# 2                  8
# 3                  3
# 4                  0
# ...              ...
# 484546            27
# 484547            11
# 484548             0
# 484549             1
# 484550            18
#
# [484551 rows x 7 columns]

# %% [markdown]
# # Check for missing data

# %%
df.isnull().sum()
# Out:
# DayOfWeek       0
# Date            0
# DepTime         0
# Airline         0
# Origin          0
# Dest            0
# CarrierDelay    0
# dtype: int64

# %% [markdown]
# # Convert Date Column to Pandas Datetime

# %%
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %% [markdown]
# # Create Month And Day Feature

# %%
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day

# %% [markdown]
# ### Drop Date now

# %%
# Drop the original 'Date' column since XGBoost doesn't handle datetime types
df = df.drop(columns=['Date'])

# %% [markdown]
# # Identify Categorical variables

# %%
categories = df.select_dtypes(include=['object']).columns
categories
# Out:
# Index(['Airline', 'Origin', 'Dest'], dtype='object')

# %% [markdown]
# # One-Hot Encoding (Dummy Variables) for Categorical Data

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# # Prepare Target Variable(s)

# %%
df_encoded['is_delayed_60+'] = np.where(df_encoded['CarrierDelay'] > 60, 1, 0)
# df_encoded['is_delayed_15+'] = np.where(df_encoded['CarrierDelay'] > 30, 1, 0)
df_encoded
# Out:
#         DayOfWeek  DepTime  CarrierDelay  month  day  \
# 0               4     1829             2      1    3
# 1               4     1937            10      1    3
# 2               4     1644             8      1    3
# 3               4     1452             3      1    3
# 4               4     1323             0      1    3
# ...           ...      ...           ...    ...  ...
# 484546          5     1609            27      6   13
# 484547          6     1616            11      6   14
# 484548          2     1617             0      6   17
# 484549          7     1607             1      6   22
# 484550          1     1608            18      6   23
#
#         Airline_American Airlines Inc.  Airline_American Eagle Airlines Inc.  \
# 0                                False                                 False
# 1                                False                                 False
# 2                                False                                 False
# 3                                False                                 False
# 4                                False                                 False
# ...                                ...                                   ...
# 484546                            True                                 False
# 484547                            True                                 False
# 484548                            True                                 False
# 484549                            True                                 False
# 484550                            True                                 False
#
#         Airline_Atlantic Southeast Airlines  Airline_Delta Air Lines Inc.  \
# 0                                     False                         False
# 1                                     False                         False
# 2                                     False                         False
# 3                                     False                         False
# 4                                     False                         False
# ...                                     ...                           ...
# 484546                                False                         False
# 484547                                False                         False
# 484548                                False                         False
# 484549                                False                         False
# 484550                                False                         False
#
#         Airline_Frontier Airlines Inc.  ...  Dest_TYS  Dest_VLD  Dest_VPS  \
# 0                                False  ...     False     False     False
# 1                                False  ...     False     False     False
# 2                                False  ...     False     False     False
# 3                                False  ...     False     False     False
# 4                                False  ...     False     False     False
# ...                                ...  ...       ...       ...       ...
# 484546                           False  ...     False     False     False
# 484547                           False  ...     False     False     False
# 484548                           False  ...     False     False     False
# 484549                           False  ...     False     False     False
# 484550                           False  ...     False     False     False
#
#         Dest_WRG  Dest_WYS  Dest_XNA  Dest_YAK  Dest_YKM  Dest_YUM  \
# 0          False     False     False     False     False     False
# 1          False     False     False     False     False     False
# 2          False     False     False     False     False     False
# 3          False     False     False     False     False     False
# 4          False     False     False     False     False     False
# ...          ...       ...       ...       ...       ...       ...
# 484546     False     False     False     False     False     False
# 484547     False     False     False     False     False     False
# 484548     False     False     False     False     False     False
# 484549     False     False     False     False     False     False
# 484550     False     False     False     False     False     False
#
#         is_delayed_60+
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 484546               0
# 484547               0
# 484548               0
# 484549               0
# 484550               0
#
# [484551 rows x 563 columns]

# %% [markdown]
# # Define features and target variable

# %%
X = df_encoded.drop(columns=['is_delayed_60+', 'CarrierDelay'])
y = df_encoded['is_delayed_60+']

# %%
X
# Out:
#         DayOfWeek  DepTime  month  day  Airline_American Airlines Inc.  \
# 0               4     1829      1    3                           False
# 1               4     1937      1    3                           False
# 2               4     1644      1    3                           False
# 3               4     1452      1    3                           False
# 4               4     1323      1    3                           False
# ...           ...      ...    ...  ...                             ...
# 484546          5     1609      6   13                            True
# 484547          6     1616      6   14                            True
# 484548          2     1617      6   17                            True
# 484549          7     1607      6   22                            True
# 484550          1     1608      6   23                            True
#
#         Airline_American Eagle Airlines Inc.  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 484546                                 False
# 484547                                 False
# 484548                                 False
# 484549                                 False
# 484550                                 False
#
#         Airline_Atlantic Southeast Airlines  Airline_Delta Air Lines Inc.  \
# 0                                     False                         False
# 1                                     False                         False
# 2                                     False                         False
# 3                                     False                         False
# 4                                     False                         False
# ...                                     ...                           ...
# 484546                                False                         False
# 484547                                False                         False
# 484548                                False                         False
# 484549                                False                         False
# 484550                                False                         False
#
#         Airline_Frontier Airlines Inc.  Airline_Hawaiian Airlines Inc.  ...  \
# 0                                False                           False  ...
# 1                                False                           False  ...
# 2                                False                           False  ...
# 3                                False                           False  ...
# 4                                False                           False  ...
# ...                                ...                             ...  ...
# 484546                           False                           False  ...
# 484547                           False                           False  ...
# 484548                           False                           False  ...
# 484549                           False                           False  ...
# 484550                           False                           False  ...
#
#         Dest_TYR  Dest_TYS  Dest_VLD  Dest_VPS  Dest_WRG  Dest_WYS  Dest_XNA  \
# 0          False     False     False     False     False     False     False
# 1          False     False     False     False     False     False     False
# 2          False     False     False     False     False     False     False
# 3          False     False     False     False     False     False     False
# 4          False     False     False     False     False     False     False
# ...          ...       ...       ...       ...       ...       ...       ...
# 484546     False     False     False     False     False     False     False
# 484547     False     False     False     False     False     False     False
# 484548     False     False     False     False     False     False     False
# 484549     False     False     False     False     False     False     False
# 484550     False     False     False     False     False     False     False
#
#         Dest_YAK  Dest_YKM  Dest_YUM
# 0          False     False     False
# 1          False     False     False
# 2          False     False     False
# 3          False     False     False
# 4          False     False     False
# ...          ...       ...       ...
# 484546     False     False     False
# 484547     False     False     False
# 484548     False     False     False
# 484549     False     False     False
# 484550     False     False     False
#
# [484551 rows x 561 columns]

# %% [markdown]
# # Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# # LightGBM with Optuna - Handling Imbalanced with SMOTE + LGBM Class Weight

# %%
# LightGBM + Optuna + SMOTE for Imbalanced Classification
import lightgbm as lgb
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score, classification_report
from imblearn.over_sampling import SMOTE

# Apply SMOTE on Training Data Only
print("Before SMOTE:", y_train.value_counts(normalize=True))
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
print("After SMOTE:", y_train_res.value_counts(normalize=True))

# Objective Function for Optuna
def objective_lgb(trial):
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'boosting_type': 'gbdt',
        'verbosity': -1,
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 50),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
        'class_weight': 'balanced',  # still keep balanced weights
        'random_state': 42
    }

    model = lgb.LGBMClassifier(**params)
    auc = cross_val_score(model, X_train_res, y_train_res, cv=3, scoring='roc_auc', n_jobs=-1).mean()
    return auc

# Run Optuna Optimization
study_lgb = optuna.create_study(direction='maximize', study_name='LightGBM_SMOTE')
study_lgb.optimize(objective_lgb, n_trials=30, show_progress_bar=True)

print("\nBest LightGBM Parameters:")
print(study_lgb.best_trial.params)

# Train Final Model with Best Parameters
best_params_lgb = study_lgb.best_trial.params
best_params_lgb['class_weight'] = 'balanced'

lgb_model = lgb.LGBMClassifier(**best_params_lgb)
lgb_model.fit(X_train_res, y_train_res)

# Evaluate Performance
y_pred_proba_lgb = lgb_model.predict_proba(X_test)[:, 1]
auc_lgb = roc_auc_score(y_test, y_pred_proba_lgb)

print(f"\nFinal LightGBM ROC-AUC: {auc_lgb:.4f}")

y_pred_lgb = lgb_model.predict(X_test)
print("\nClassification Report:\n", classification_report(y_test, y_pred_lgb))
# Out:
# Before SMOTE: is_delayed_60+
# 0    0.925383
# 1    0.074617
# Name: proportion, dtype: float64
# [I 2025-11-07 15:41:49,669] A new study created in memory with name: LightGBM_SMOTE
# After SMOTE: is_delayed_60+
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-11-07 15:42:41,387] Trial 0 finished with value: 0.954436414319369 and parameters: {'learning_rate': 0.08764692155766368, 'num_leaves': 50, 'max_depth': 7, 'min_child_samples': 18, 'subsample': 0.9944727504645015, 'colsample_bytree': 0.8300157398703177, 'reg_alpha': 0.003262389488358145, 'reg_lambda': 0.05316371173685842}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:43:18,648] Trial 1 finished with value: 0.9332205059109734 and parameters: {'learning_rate': 0.05517836379231984, 'num_leaves': 47, 'max_depth': 4, 'min_child_samples': 95, 'subsample': 0.6722797732962758, 'colsample_bytree': 0.9873615803667232, 'reg_alpha': 0.025127122850845868, 'reg_lambda': 0.023796387593808737}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:44:02,719] Trial 2 finished with value: 0.9180913267367027 and parameters: {'learning_rate': 0.04541255641653459, 'num_leaves': 34, 'max_depth': 3, 'min_child_samples': 41, 'subsample': 0.6875257017345915, 'colsample_bytree': 0.5077836058100389, 'reg_alpha': 4.73178205508757, 'reg_lambda': 3.9352447898060845}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:44:55,236] Trial 3 finished with value: 0.9489609112701872 and parameters: {'learning_rate': 0.07332295822228874, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 44, 'subsample': 0.6018615124522457, 'colsample_bytree': 0.5741528988099474, 'reg_alpha': 5.760369099684348, 'reg_lambda': 0.001034628264845773}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:45:38,870] Trial 4 finished with value: 0.9338343924472922 and parameters: {'learning_rate': 0.02860159955991444, 'num_leaves': 37, 'max_depth': 6, 'min_child_samples': 65, 'subsample': 0.9664387817082933, 'colsample_bytree': 0.7249870507402764, 'reg_alpha': 1.635087085416204, 'reg_lambda': 0.05181758583354989}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:46:26,093] Trial 5 finished with value: 0.9488227600203034 and parameters: {'learning_rate': 0.070526746452053, 'num_leaves': 40, 'max_depth': 6, 'min_child_samples': 40, 'subsample': 0.7314594883512885, 'colsample_bytree': 0.6674961642731064, 'reg_alpha': 0.7696822400489564, 'reg_lambda': 0.06048945887295093}. Best is trial 0 with value: 0.954436414319369.
# [I 2025-11-07 15:47:14,303] Trial 6 finished with value: 0.9645180191977406 and parameters: {'learning_rate': 0.19880690870480838, 'num_leaves': 34, 'max_depth': 9, 'min_child_samples': 66, 'subsample': 0.8201464248746817, 'colsample_bytree': 0.6677475138048056, 'reg_alpha': 0.03245600139460358, 'reg_lambda': 1.9946013458116822}. Best is trial 6 with value: 0.9645180191977406.
# [I 2025-11-07 15:48:05,645] Trial 7 finished with value: 0.9410975164026779 and parameters: {'learning_rate': 0.026154787658422, 'num_leaves': 42, 'max_depth': 7, 'min_child_samples': 25, 'subsample': 0.6289410424803523, 'colsample_bytree': 0.6005225915148198, 'reg_alpha': 0.19919673898712564, 'reg_lambda': 0.03001898007355631}. Best is trial 6 with value: 0.9645180191977406.
# [I 2025-11-07 15:49:04,460] Trial 8 finished with value: 0.9595079047090862 and parameters: {'learning_rate': 0.09629571600498393, 'num_leaves': 34, 'max_depth': 9, 'min_child_samples': 18, 'subsample': 0.644617812804003, 'colsample_bytree': 0.5060966180797168, 'reg_alpha': 0.17035633615241405, 'reg_lambda': 0.03768134908597975}. Best is trial 6 with value: 0.9645180191977406.
# [I 2025-11-07 15:49:46,065] Trial 9 finished with value: 0.9401410129112967 and parameters: {'learning_rate': 0.12410846987851012, 'num_leaves': 32, 'max_depth': 3, 'min_child_samples': 60, 'subsample': 0.9405366287172772, 'colsample_bytree': 0.7076426557580822, 'reg_alpha': 0.11673700751048471, 'reg_lambda': 0.04782158762626244}. Best is trial 6 with value: 0.9645180191977406.
# [I 2025-11-07 15:50:32,049] Trial 10 finished with value: 0.932354221322873 and parameters: {'learning_rate': 0.011349920601361039, 'num_leaves': 23, 'max_depth': 10, 'min_child_samples': 85, 'subsample': 0.8124816907664839, 'colsample_bytree': 0.8428679045208338, 'reg_alpha': 0.0011192340427125245, 'reg_lambda': 8.101573016165233}. Best is trial 6 with value: 0.9645180191977406.
# [I 2025-11-07 15:51:25,256] Trial 11 finished with value: 0.9647425748316826 and parameters: {'learning_rate': 0.18712842349714823, 'num_leaves': 28, 'max_depth': 10, 'min_child_samples': 74, 'subsample': 0.8428599147814567, 'colsample_bytree': 0.516086529749887, 'reg_alpha': 0.026749801414758266, 'reg_lambda': 0.7740514522792545}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:52:17,766] Trial 12 finished with value: 0.9641689844398235 and parameters: {'learning_rate': 0.19848366746255755, 'num_leaves': 27, 'max_depth': 9, 'min_child_samples': 73, 'subsample': 0.8012220522771599, 'colsample_bytree': 0.6086131656495395, 'reg_alpha': 0.016508943724348624, 'reg_lambda': 0.9500059570621902}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:53:02,309] Trial 13 finished with value: 0.9644331868550996 and parameters: {'learning_rate': 0.18495452269213952, 'num_leaves': 28, 'max_depth': 10, 'min_child_samples': 80, 'subsample': 0.8794032877112509, 'colsample_bytree': 0.837056181306685, 'reg_alpha': 0.019082919713290354, 'reg_lambda': 0.8760347284003522}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:53:50,136] Trial 14 finished with value: 0.9603825474043607 and parameters: {'learning_rate': 0.14678170502478036, 'num_leaves': 23, 'max_depth': 8, 'min_child_samples': 96, 'subsample': 0.5164373546567305, 'colsample_bytree': 0.6626652924917907, 'reg_alpha': 0.0061876074781726026, 'reg_lambda': 0.3944199101071621}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:54:41,014] Trial 15 finished with value: 0.960014156897929 and parameters: {'learning_rate': 0.11833828908273987, 'num_leaves': 29, 'max_depth': 9, 'min_child_samples': 52, 'subsample': 0.8620080404838637, 'colsample_bytree': 0.5645206633224829, 'reg_alpha': 0.044339055132936636, 'reg_lambda': 0.26861358872837665}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:55:24,508] Trial 16 finished with value: 0.9341467811919836 and parameters: {'learning_rate': 0.02371341470390788, 'num_leaves': 20, 'max_depth': 8, 'min_child_samples': 72, 'subsample': 0.7788235495813424, 'colsample_bytree': 0.7789893561213314, 'reg_alpha': 0.006700794504706494, 'reg_lambda': 2.0642178922575556}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:56:07,784] Trial 17 finished with value: 0.9630541369624126 and parameters: {'learning_rate': 0.15487555625116792, 'num_leaves': 31, 'max_depth': 10, 'min_child_samples': 84, 'subsample': 0.882314358765731, 'colsample_bytree': 0.9318835512202989, 'reg_alpha': 0.48932448088545116, 'reg_lambda': 0.22781551076707107}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:56:55,881] Trial 18 finished with value: 0.9324527755488546 and parameters: {'learning_rate': 0.01097990252302863, 'num_leaves': 25, 'max_depth': 8, 'min_child_samples': 52, 'subsample': 0.729281729054814, 'colsample_bytree': 0.6740328169442639, 'reg_alpha': 0.050854511169489254, 'reg_lambda': 2.0230316805352486}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:57:45,428] Trial 19 finished with value: 0.9503644223926239 and parameters: {'learning_rate': 0.11154279818767748, 'num_leaves': 44, 'max_depth': 5, 'min_child_samples': 67, 'subsample': 0.8375719105092342, 'colsample_bytree': 0.5483856954073766, 'reg_alpha': 0.0011547657861281212, 'reg_lambda': 0.008643834502194553}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:58:37,569] Trial 20 finished with value: 0.9399340505335747 and parameters: {'learning_rate': 0.01640761428933998, 'num_leaves': 37, 'max_depth': 9, 'min_child_samples': 29, 'subsample': 0.9238234261201657, 'colsample_bytree': 0.6286409774686088, 'reg_alpha': 0.05676028590004725, 'reg_lambda': 9.981028132843726}. Best is trial 11 with value: 0.9647425748316826.
# [I 2025-11-07 15:59:21,509] Trial 21 finished with value: 0.9650190642147392 and parameters: {'learning_rate': 0.19811921898652773, 'num_leaves': 29, 'max_depth': 10, 'min_child_samples': 81, 'subsample': 0.9054174908881463, 'colsample_bytree': 0.8077674609561654, 'reg_alpha': 0.014350306236186147, 'reg_lambda': 0.729027628264848}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:00:04,420] Trial 22 finished with value: 0.9649227608328247 and parameters: {'learning_rate': 0.1922714252469425, 'num_leaves': 32, 'max_depth': 10, 'min_child_samples': 78, 'subsample': 0.9166559003261555, 'colsample_bytree': 0.7722250078795231, 'reg_alpha': 0.0068720451549146196, 'reg_lambda': 0.7862452367061077}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:00:50,050] Trial 23 finished with value: 0.962826897306608 and parameters: {'learning_rate': 0.1474097191042881, 'num_leaves': 30, 'max_depth': 10, 'min_child_samples': 88, 'subsample': 0.9139519449260365, 'colsample_bytree': 0.7829867873177964, 'reg_alpha': 0.008318818128896285, 'reg_lambda': 0.7066482372275424}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:01:34,003] Trial 24 finished with value: 0.9630553141903305 and parameters: {'learning_rate': 0.15782540694525182, 'num_leaves': 26, 'max_depth': 10, 'min_child_samples': 77, 'subsample': 0.9917933313089539, 'colsample_bytree': 0.8957078614488247, 'reg_alpha': 0.0031790958893629364, 'reg_lambda': 0.20926579302469367}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:02:19,384] Trial 25 finished with value: 0.9551886135682818 and parameters: {'learning_rate': 0.08858553775495812, 'num_leaves': 31, 'max_depth': 8, 'min_child_samples': 92, 'subsample': 0.9004126886988152, 'colsample_bytree': 0.7661654969940067, 'reg_alpha': 0.011793825859526598, 'reg_lambda': 0.14754287948637312}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:03:01,545] Trial 26 finished with value: 0.9604914641626143 and parameters: {'learning_rate': 0.12799854681728354, 'num_leaves': 24, 'max_depth': 10, 'min_child_samples': 100, 'subsample': 0.8448525670822594, 'colsample_bytree': 0.8863273169510072, 'reg_alpha': 0.003138383778917824, 'reg_lambda': 0.7361980813424169}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:03:47,739] Trial 27 finished with value: 0.9453599936393374 and parameters: {'learning_rate': 0.03395570533477355, 'num_leaves': 28, 'max_depth': 10, 'min_child_samples': 77, 'subsample': 0.9456806023579524, 'colsample_bytree': 0.8084885876266102, 'reg_alpha': 0.08908018136841606, 'reg_lambda': 0.40564788183734446}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:04:35,730] Trial 28 finished with value: 0.9635515602476806 and parameters: {'learning_rate': 0.1690598151545072, 'num_leaves': 37, 'max_depth': 9, 'min_child_samples': 59, 'subsample': 0.7559067686305873, 'colsample_bytree': 0.7353268343002274, 'reg_alpha': 0.0047262750146626654, 'reg_lambda': 4.733862466003676}. Best is trial 21 with value: 0.9650190642147392.
# [I 2025-11-07 16:05:18,681] Trial 29 finished with value: 0.9514309188788653 and parameters: {'learning_rate': 0.07445871803976223, 'num_leaves': 32, 'max_depth': 7, 'min_child_samples': 71, 'subsample': 0.9993437274742869, 'colsample_bytree': 0.8800786466591163, 'reg_alpha': 0.0018817880387112687, 'reg_lambda': 0.10464935870394158}. Best is trial 21 with value: 0.9650190642147392.
#
# Best LightGBM Parameters:
# {'learning_rate': 0.19811921898652773, 'num_leaves': 29, 'max_depth': 10, 'min_child_samples': 81, 'subsample': 0.9054174908881463, 'colsample_bytree': 0.8077674609561654, 'reg_alpha': 0.014350306236186147, 'reg_lambda': 0.729027628264848}
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 313876, number of negative: 313876
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015934 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1160
# [LightGBM] [Info] Number of data points in the train set: 627752, number of used features: 433
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# Final LightGBM ROC-AUC: 0.6659
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96    134383
#            1       0.27      0.05      0.09     10983
#
#     accuracy                           0.92    145366
#    macro avg       0.60      0.52      0.52    145366
# weighted avg       0.88      0.92      0.89    145366

# %%
# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_lgb)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_lgb:.4f}')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# # CatBoost with Optuna

# %%
from catboost import CatBoostClassifier, Pool
import optuna
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE

# Apply SMOTE on Training Data Only
print("Before SMOTE:", y_train.value_counts(normalize=True))
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
print("After SMOTE:", y_train_res.value_counts(normalize=True))

def objective_catboost(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 30, 50),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-2, 10.0, log=True),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'random_strength': trial.suggest_float('random_strength', 0.1, 2.0),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations', 1, 10),
        'loss_function': 'Logloss',
        'eval_metric': 'AUC',
        'verbose': False,
        'random_seed': 42
    }

    model = CatBoostClassifier(**params)

    # 3-fold cross-validation ROC-AUC
    auc = cross_val_score(model, X_train_res, y_train_res, cv=3, scoring='roc_auc', n_jobs=-1).mean()
    return auc

# Create study
study_cat = optuna.create_study(direction='maximize')
study_cat.optimize(objective_catboost, n_trials=30, show_progress_bar=True)

print("\nBest CatBoost Parameters:")
print(study_cat.best_trial.params)

# Train final CatBoost model
best_params_cat = study_cat.best_trial.params
cat_model = CatBoostClassifier(**best_params_cat)
cat_model.fit(X_train_res, y_train_res, verbose=False)

# Evaluate
y_pred_cat = cat_model.predict(X_test)
y_pred_proba_cat = cat_model.predict_proba(X_test)[:, 1]
auc_cat = roc_auc_score(y_test, y_pred_proba_cat)

print(f"\n Best CatBoost ROC-AUC on Test Set: {auc_cat:.4f}")
# Out:
# Before SMOTE: is_delayed_60+
# 0    0.925383
# 1    0.074617
# Name: proportion, dtype: float64
# [I 2025-11-07 16:43:46,424] A new study created in memory with name: no-name-a1729b44-0fef-483b-9cf0-8c6d031e97d9
# After SMOTE: is_delayed_60+
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#   0%|          | 0/30 [00:00<?, ?it/s]
# [I 2025-11-07 16:44:47,263] Trial 0 finished with value: 0.93816245756426 and parameters: {'iterations': 42, 'learning_rate': 0.10219949101490865, 'depth': 7, 'l2_leaf_reg': 0.3673989419223611, 'bagging_temperature': 0.09540461170081449, 'border_count': 54, 'random_strength': 0.7435765691228053, 'leaf_estimation_iterations': 5}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:45:41,649] Trial 1 finished with value: 0.9326816412797793 and parameters: {'iterations': 45, 'learning_rate': 0.07516708954731013, 'depth': 7, 'l2_leaf_reg': 0.49903154384358034, 'bagging_temperature': 0.3721240663298383, 'border_count': 173, 'random_strength': 0.183678313770617, 'leaf_estimation_iterations': 3}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:46:33,882] Trial 2 finished with value: 0.9272293699496229 and parameters: {'iterations': 38, 'learning_rate': 0.07934826487704086, 'depth': 6, 'l2_leaf_reg': 1.246627838813271, 'bagging_temperature': 0.9337304240507072, 'border_count': 128, 'random_strength': 1.604852277446461, 'leaf_estimation_iterations': 3}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:47:29,020] Trial 3 finished with value: 0.9226459533896035 and parameters: {'iterations': 39, 'learning_rate': 0.045699320092789666, 'depth': 7, 'l2_leaf_reg': 3.3535392561643826, 'bagging_temperature': 0.16185690846112954, 'border_count': 43, 'random_strength': 0.519294135457728, 'leaf_estimation_iterations': 6}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:48:30,933] Trial 4 finished with value: 0.9246450012657085 and parameters: {'iterations': 45, 'learning_rate': 0.023392245807932664, 'depth': 10, 'l2_leaf_reg': 2.0773921252679384, 'bagging_temperature': 0.16486164826136374, 'border_count': 113, 'random_strength': 0.6858104118642214, 'leaf_estimation_iterations': 4}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:49:22,601] Trial 5 finished with value: 0.8978306858901132 and parameters: {'iterations': 38, 'learning_rate': 0.023512264804735665, 'depth': 6, 'l2_leaf_reg': 0.015465326094616486, 'bagging_temperature': 0.17633045871622655, 'border_count': 110, 'random_strength': 0.8338768967370122, 'leaf_estimation_iterations': 1}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:50:14,796] Trial 6 finished with value: 0.9254317852726182 and parameters: {'iterations': 37, 'learning_rate': 0.0919617023499189, 'depth': 5, 'l2_leaf_reg': 0.02120382153437659, 'bagging_temperature': 0.9408262050067209, 'border_count': 217, 'random_strength': 0.33716796309490726, 'leaf_estimation_iterations': 4}. Best is trial 0 with value: 0.93816245756426.
# [I 2025-11-07 16:51:10,981] Trial 7 finished with value: 0.9443637552375262 and parameters: {'iterations': 36, 'learning_rate': 0.1733595446307336, 'depth': 7, 'l2_leaf_reg': 1.9053576212579109, 'bagging_temperature': 0.7376662917231592, 'border_count': 45, 'random_strength': 0.3428910948330778, 'leaf_estimation_iterations': 10}. Best is trial 7 with value: 0.9443637552375262.
# [I 2025-11-07 16:52:03,080] Trial 8 finished with value: 0.8823105805259946 and parameters: {'iterations': 45, 'learning_rate': 0.013879741650360997, 'depth': 6, 'l2_leaf_reg': 1.5613437180535412, 'bagging_temperature': 0.7898220529688164, 'border_count': 153, 'random_strength': 1.5667896896408282, 'leaf_estimation_iterations': 1}. Best is trial 7 with value: 0.9443637552375262.
# [I 2025-11-07 16:52:57,878] Trial 9 finished with value: 0.9281274150052283 and parameters: {'iterations': 42, 'learning_rate': 0.09448714692322865, 'depth': 5, 'l2_leaf_reg': 0.023100523194505004, 'bagging_temperature': 0.27852462765659547, 'border_count': 156, 'random_strength': 1.494907039852874, 'leaf_estimation_iterations': 10}. Best is trial 7 with value: 0.9443637552375262.
# [I 2025-11-07 16:53:56,384] Trial 10 finished with value: 0.948229510317958 and parameters: {'iterations': 30, 'learning_rate': 0.1877971930264329, 'depth': 9, 'l2_leaf_reg': 8.510585750615553, 'bagging_temperature': 0.5991149757603331, 'border_count': 82, 'random_strength': 1.1741306704043382, 'leaf_estimation_iterations': 10}. Best is trial 10 with value: 0.948229510317958.
# [I 2025-11-07 16:54:51,777] Trial 11 finished with value: 0.9495644303171833 and parameters: {'iterations': 30, 'learning_rate': 0.19950838057564113, 'depth': 9, 'l2_leaf_reg': 8.23516943944759, 'bagging_temperature': 0.6220809244390914, 'border_count': 76, 'random_strength': 1.2601251793642236, 'leaf_estimation_iterations': 10}. Best is trial 11 with value: 0.9495644303171833.
# [I 2025-11-07 16:55:51,937] Trial 12 finished with value: 0.9486801952396009 and parameters: {'iterations': 30, 'learning_rate': 0.16495359559471587, 'depth': 10, 'l2_leaf_reg': 8.729977341608993, 'bagging_temperature': 0.5626839559685085, 'border_count': 88, 'random_strength': 1.1898309938713338, 'leaf_estimation_iterations': 8}. Best is trial 11 with value: 0.9495644303171833.
# [I 2025-11-07 16:56:46,858] Trial 13 finished with value: 0.9452566504198919 and parameters: {'iterations': 30, 'learning_rate': 0.15191112653980557, 'depth': 9, 'l2_leaf_reg': 9.721245619402378, 'bagging_temperature': 0.5111474358758782, 'border_count': 88, 'random_strength': 1.1798929804892568, 'leaf_estimation_iterations': 8}. Best is trial 11 with value: 0.9495644303171833.
# [I 2025-11-07 16:57:45,734] Trial 14 finished with value: 0.9310714931236044 and parameters: {'iterations': 32, 'learning_rate': 0.049668014707066166, 'depth': 10, 'l2_leaf_reg': 0.11959117005542506, 'bagging_temperature': 0.5915342917701819, 'border_count': 79, 'random_strength': 1.9670594122164822, 'leaf_estimation_iterations': 8}. Best is trial 11 with value: 0.9495644303171833.
# [I 2025-11-07 16:58:48,224] Trial 15 finished with value: 0.9506330291879478 and parameters: {'iterations': 50, 'learning_rate': 0.13476057815746015, 'depth': 9, 'l2_leaf_reg': 4.681355712619751, 'bagging_temperature': 0.41312142222772263, 'border_count': 238, 'random_strength': 1.0031580059072147, 'leaf_estimation_iterations': 8}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 16:59:49,260] Trial 16 finished with value: 0.9496000814723923 and parameters: {'iterations': 49, 'learning_rate': 0.12877431396197622, 'depth': 9, 'l2_leaf_reg': 0.08333237881784954, 'bagging_temperature': 0.37352931231856173, 'border_count': 241, 'random_strength': 0.8809849712430442, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:00:48,175] Trial 17 finished with value: 0.9463942344833923 and parameters: {'iterations': 50, 'learning_rate': 0.12031236647554486, 'depth': 8, 'l2_leaf_reg': 0.09569119155566842, 'bagging_temperature': 0.3935094426977124, 'border_count': 252, 'random_strength': 0.961115160024664, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:01:46,782] Trial 18 finished with value: 0.9357928626321509 and parameters: {'iterations': 50, 'learning_rate': 0.060987837514268124, 'depth': 8, 'l2_leaf_reg': 0.07256144366583239, 'bagging_temperature': 0.0026166399079132763, 'border_count': 203, 'random_strength': 0.9637241207313503, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:02:46,336] Trial 19 finished with value: 0.9476256885762009 and parameters: {'iterations': 48, 'learning_rate': 0.13135247808527845, 'depth': 8, 'l2_leaf_reg': 0.05618551609142778, 'bagging_temperature': 0.40167559506968903, 'border_count': 250, 'random_strength': 0.5762432907172998, 'leaf_estimation_iterations': 6}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:03:46,151] Trial 20 finished with value: 0.9027974667076671 and parameters: {'iterations': 47, 'learning_rate': 0.03085561077109321, 'depth': 4, 'l2_leaf_reg': 0.21246657248961234, 'bagging_temperature': 0.30839203836264223, 'border_count': 218, 'random_strength': 1.3783070232447925, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:04:43,266] Trial 21 finished with value: 0.9505320504864891 and parameters: {'iterations': 34, 'learning_rate': 0.19091268001786146, 'depth': 9, 'l2_leaf_reg': 4.700759120681873, 'bagging_temperature': 0.6900575293847809, 'border_count': 187, 'random_strength': 1.3553524923598042, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:05:39,796] Trial 22 finished with value: 0.94502310302883 and parameters: {'iterations': 35, 'learning_rate': 0.1270754699077625, 'depth': 9, 'l2_leaf_reg': 0.766011866274577, 'bagging_temperature': 0.7349127857018285, 'border_count': 193, 'random_strength': 1.7418174589399738, 'leaf_estimation_iterations': 7}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:06:35,226] Trial 23 finished with value: 0.9288582928101666 and parameters: {'iterations': 34, 'learning_rate': 0.06317283602886949, 'depth': 8, 'l2_leaf_reg': 4.500717480887, 'bagging_temperature': 0.4343614745570367, 'border_count': 225, 'random_strength': 1.0329951251935778, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:07:38,481] Trial 24 finished with value: 0.9487668771480555 and parameters: {'iterations': 48, 'learning_rate': 0.12119981577762395, 'depth': 9, 'l2_leaf_reg': 0.21561670378636413, 'bagging_temperature': 0.47851247120818174, 'border_count': 237, 'random_strength': 0.8593603342046876, 'leaf_estimation_iterations': 9}. Best is trial 15 with value: 0.9506330291879478.
# [I 2025-11-07 17:08:43,048] Trial 25 finished with value: 0.9521899408784731 and parameters: {'iterations': 43, 'learning_rate': 0.1486736719197068, 'depth': 10, 'l2_leaf_reg': 3.885564038258831, 'bagging_temperature': 0.2801466867996395, 'border_count': 186, 'random_strength': 1.3800421791973265, 'leaf_estimation_iterations': 8}. Best is trial 25 with value: 0.9521899408784731.
# [I 2025-11-07 17:09:46,309] Trial 26 finished with value: 0.9167818351396644 and parameters: {'iterations': 42, 'learning_rate': 0.010332005675472038, 'depth': 10, 'l2_leaf_reg': 4.089492736346069, 'bagging_temperature': 0.24364219248426922, 'border_count': 180, 'random_strength': 1.371690393429971, 'leaf_estimation_iterations': 8}. Best is trial 25 with value: 0.9521899408784731.
# [I 2025-11-07 17:10:51,228] Trial 27 finished with value: 0.9513531891353635 and parameters: {'iterations': 40, 'learning_rate': 0.1569108846198083, 'depth': 10, 'l2_leaf_reg': 2.9036631434746867, 'bagging_temperature': 0.6898726233075811, 'border_count': 199, 'random_strength': 1.8449918658886333, 'leaf_estimation_iterations': 9}. Best is trial 25 with value: 0.9521899408784731.
# [I 2025-11-07 17:11:55,402] Trial 28 finished with value: 0.9281377023876319 and parameters: {'iterations': 41, 'learning_rate': 0.031363640623916916, 'depth': 10, 'l2_leaf_reg': 0.9123462327688117, 'bagging_temperature': 0.5063585409929275, 'border_count': 208, 'random_strength': 1.9240716416718646, 'leaf_estimation_iterations': 8}. Best is trial 25 with value: 0.9521899408784731.
# [I 2025-11-07 17:12:58,445] Trial 29 finished with value: 0.9468671459696406 and parameters: {'iterations': 43, 'learning_rate': 0.10352861063005736, 'depth': 10, 'l2_leaf_reg': 2.8615754053508686, 'bagging_temperature': 0.8821930554035871, 'border_count': 170, 'random_strength': 1.803925733534574, 'leaf_estimation_iterations': 5}. Best is trial 25 with value: 0.9521899408784731.
#
# Best CatBoost Parameters:
# {'iterations': 43, 'learning_rate': 0.1486736719197068, 'depth': 10, 'l2_leaf_reg': 3.885564038258831, 'bagging_temperature': 0.2801466867996395, 'border_count': 186, 'random_strength': 1.3800421791973265, 'leaf_estimation_iterations': 8}
#
#  Best CatBoost ROC-AUC on Test Set: 0.6477

# %%
# Plot the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_cat)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_cat:.4f}')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random guessing
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
